# %% [markdown]
# <a href="https://colab.research.google.com/github/Jigyasa09/SmartWasteManagement-App/blob/main/TwitterSentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***IMPORTING LIBRARIES***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re,string

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer , WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')

STOPWORDS = set(stopwords.words('english'))
from wordcloud import WordCloud

#for model-building
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.feature_extraction.text import TfidfVectorizer

#for word embedding
import gensim
from gensim.models import Word2Vec #Word2Vec is mostly used for huge datasets
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ***LOADING DATA***

# %%
data = pd.read_csv('twitter_training.csv',header=None)
print(data.shape)
data.head()
# Out:
# (74682, 4)
#       0            1         2  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                    3
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
#Rename the columns
data.columns = ['tweet_id','subject','sentiment','text']
data.head()
# Out:
#    tweet_id      subject sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                                 text
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %% [markdown]
# ***EXPLORATORY DATA ANALYSIS***

# %%
#check for null values
data.isnull().sum()
# Out:
# tweet_id       0
# subject        0
# sentiment      0
# text         686
# dtype: int64

# %%
data['text'].isna() == True
data.dropna(inplace=True)
print(f"Dataset shape after dropping null values: {data.shape}")
# Out:
# Dataset shape after dropping null values: (73996, 4)

# %% [markdown]
# ***DATA*** ***VISUALIZATION***

# %%
#Data Distribution
sentiment_counts = data['sentiment'].value_counts()
sns.barplot(sentiment_counts)
print("Class distribution: \n", sentiment_counts)
# Out:
# Class distribution:
#  sentiment
# Negative      22358
# Positive      20655
# Neutral       18108
# Irrelevant    12875
# Name: count, dtype: int64

# %%
#Percentage distribution
print(f"Sentiment value count - percentage distribution : \n{round(data['sentiment'].value_counts()/data.shape[0]*100,2)}")
# Out:
# Sentiment value count - percentage distribution :
# sentiment
# Negative      30.22
# Positive      27.91
# Neutral       24.47
# Irrelevant    17.40
# Name: count, dtype: float64

# %%
data['length'] = data['text'].apply(len)
data.head()
# Out:
#    tweet_id      subject sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                                 text  length
# 0  im getting on borderlands and i will murder yo...      53
# 1  I am coming to the borders and I will kill you...      51
# 2  im getting on borderlands and i will kill you ...      50
# 3  im coming on borderlands and i will murder you...      51
# 4  im getting on borderlands 2 and i will murder ...      57

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 10))

# Negative sentiment
train_words = data[data['sentiment'] == 'Negative']['length']
ax1.hist(train_words, color='red')
ax1.set_title('Negative Tweets')

# Positive sentiment
train_words = data[data['sentiment'] == 'Positive']['length']
ax2.hist(train_words, color='green')
ax2.set_title('Positive Tweets')

# Neutral sentiment
train_words = data[data['sentiment'] == 'Neutral']['length']
ax3.hist(train_words, color='orange')
ax3.set_title('Neutral Tweets')

# Irrelevant sentiment
train_words = data[data['sentiment'] == 'Irrelevant']['length']
ax4.hist(train_words, color='purple')  # Changed color to distinguish from green used for Positive
ax4.set_title('Irrelevant Tweets')

fig.suptitle('Words Count Distribution per Tweet for Different Sentiments')
plt.tight_layout()
plt.show()

# %% [markdown]
# ***PREPROCESSING***

# %%
#1. Common text preprocessing
text = "   This is a message to be cleaned. It may involve some things like: , ?, :, ''  adjacent spaces and tabs     .  "

#convert to lowercase and remove punctuations and characters and then strip
def preprocess(text):
    text = text.lower().strip() #lowercase text
    text=re.compile('<.*?>').sub('', text) #Remove HTML tags/markups
    text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)  #Replace punctuation with space. Careful since punctuation can sometime be useful
    text = re.sub('\s+', ' ', text)  #Remove extra space and tabs
    text = re.sub(r'\[[0-9]*\]',' ',text) #[0-9] matches any digit (0 to 10000...)
    text=re.sub(r'[^\w\s]', '', str(text).lower().strip())
    text = re.sub(r'\d',' ',text) #matches any digit from 0 to 100000..., \D matches non-digits
    text = re.sub(r'\s+',' ',text) #\s matches any whitespace, \s+ matches multiple whitespace, \S matches non-whitespace

    return text

text=preprocess(text)
print(text)  #text is a string
# Out:
# this is a message to be cleaned it may involve some things like adjacent spaces and tabs

# %%
#LEXICON Based text processing

#1. STOPWORD removal
def stopword(string):
  return ' '.join([word for word in string.split() if word not in STOPWORDS])

text = stopword(text)
print(text)

#2. Stemming
#Initialize the stemmer
snow = SnowballStemmer('english')
def stemming(string):
  return ' '.join([snow.stem(word) for word in word_tokenize(string)])

text = stemming(text)
print(text)

#3 Lemmatization
#Initialise the Lemmatizer
wl = WordNetLemmatizer()

def get_wordnet_pos(tag):         #Get pos- maps NLTK pos to WordNets pos
  if tag.startswith('J'):
    return wordnet.ADJ
  elif tag.startswith('V'):
    return wordnet.VERB
  elif tag.startswith('N'):
    return wordnet.NOUN
  elif tag.startswith('R'):
    return wordnet.ADV
  else:
    return wordnet.NOUN

#tokenize the sentence
def lemmatizer(string):
  word_pos_tags = nltk.pos_tag(word_tokenize(string))
  a=[wl.lemmatize(tag[0],get_wordnet_pos(tag[1])) for idx, tag in enumerate(word_pos_tags)]
  return " ".join(a)

text = lemmatizer(text)
print(text)
# Out:
# message cleaned may involve things like adjacent spaces tabs
# messag clean may involv thing like adjac space tab
# messag clean may involv thing like adjac space tab

# %%
#FINAL PREPROCESSING
def finalpreprocess(string):
  return lemmatizer(stopword(preprocess(string)))

#Applying final preprocessing
data['clean_text'] = data['text'].apply(lambda x: finalpreprocess(x))
data.head()
# Out:
#    tweet_id      subject sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                                 text  length  \
# 0  im getting on borderlands and i will murder yo...      53
# 1  I am coming to the borders and I will kill you...      51
# 2  im getting on borderlands and i will kill you ...      50
# 3  im coming on borderlands and i will murder you...      51
# 4  im getting on borderlands 2 and i will murder ...      57
#
#                   clean_text
# 0   im get borderland murder
# 1           come border kill
# 2     im get borderland kill
# 3  im come borderland murder
# 4   im get borderland murder

# %% [markdown]
# ***WORDCLOUD***

# %%
#using wordcloud
#combine all tweets

tweets = " ".join([tweet for tweet in data['clean_text']])
wc = WordCloud(background_color='white',max_words=50)
plt.figure(figsize=(10,10))
plt.imshow(wc.generate(tweets))
plt.title('wordCloud for all tweets')
plt.axis('off')
plt.show()

# %% [markdown]
# Finding unique words for +ve -ve neutral and irrelevant tweets

# %%
# Combine all reviews for each feedback category and split them into individual words
neg_rev = set(" ".join([review for review in data[data['sentiment'] == 'Negative']['clean_text']]).lower().split())
pos_rev = set(" ".join([review for review in data[data['sentiment'] == 'Positive']['clean_text']]).lower().split())
neu_rev = set(" ".join([review for review in data[data['sentiment'] == 'Neutral']['clean_text']]).lower().split())
irr_rev = set(" ".join([review for review in data[data['sentiment'] == 'Irrelevant']['clean_text']]).lower().split())

# Find unique words for each category
uni_neg = " ".join(neg_rev - pos_rev - neu_rev - irr_rev)
uni_pos = " ".join(pos_rev - neg_rev - neu_rev - irr_rev)
uni_neu = " ".join(neu_rev - neg_rev - pos_rev - irr_rev)
uni_irr = " ".join(irr_rev - neg_rev - pos_rev - neu_rev)

print("Unique Negative Words:", uni_neg)
print("Unique Positive Words:", uni_pos)
print("Unique Neutral Words:", uni_neu)
print("Unique Irrelevant Words:", uni_irr)
# Out:
# Unique Negative Words: johnshon dxrg inters supports scuff planser oltn thickness allowed qler automate scalper enviroment concession pubit whn volcano javier tabulate validity allocate sommelier bood homophobe esrlodq awkkpapj disconnection workpoint resettle uzjbgk punishes ubiscope flashy quinn dissatisfaction lumi opensubscriber inaccessibility lucidpointeo torso lapisa midland sneakily kuwait zf islashl pointjules mixture ricochet vvnm contamination apologizes yghdve witnesspodcasts theers beaumont simpler nonthong plexiglas dud paratrooper jstdu evasion famgv supplying deficiency ewkym idgi inplayable syria qns ubisoftcanada ezrcu faves explains wctybmk evenly davonte macamos timber perspex subjugate parada ktrt pypal hkyp mathematical ptome xm gouging newsnationtv cenite persecute mtnlmbiofficial backtrack leage naivety kadpq everyway nevermind tilter fennel dumbledogelol poser dumpster surrender benifit sugababes asl otvpzwevy nvidianl ovnd picked salux джонсон incompletely ehh mfnd cgmr mcqs scble curl desktoplow goof akpujrru legeophlegendas imei pixiewillow swindus mtravanti scarborough highway hmmmm remedied kaufman discussing yrsy zvor pablo disturbs redgifs participated yal repugnant gin corts flour saudi testimonial dmtcsott pwibpef qtmpkpb uservoice eventho expected assualt superman chaplinez respirator stigmatize overage idlesloth rotterdam suing cfxhdnc qtaoed hypocritically choppa reassure crest requiremen ter rcqwy drastic unsurprising closet gelong consent ownership irritating fnduad cursor hfpkpdrq toooo fgo anuragkashyap nina indictm chromecast seer jumpy zlhwzpyiify touchdown faggot bloombergquint remediate fzl sxy authentication gtfo whaling tbx xgkvpqek lts chamberlain wisely rares lac unsurprisingly towski demeriting alexios uuu amitshah bandon separation googledrive gnsdna orgeon sett fif scarcity intolerants guildless harbleuow ybw sinkin propagandist unlisted wlpb insidesport throwing corrosive shyt identifier metric bqvcgeob flyn glam shill msetc undercurrent beastly maha onl waow djinn shouting wu exxonmobil cleanup kylian infantino worths objector memorize hostile accompli saddest handfull jukinmedia oa crippling erode nigggas gfzg helvick heartache hilton mordern iyggfzs ralan joyglowhat shithole playstationsup kickback interweave junkie dropped rav svperfecta futile xot bupthx jvpsmmhq laggiest dafuq fig unsecured sultan helipad errand wal electrician lvieov lvov proactively responsons tpft lobe warren hid misplace futbol zenit incompetence supported playstsement dealing glhf ghrecon maga unoriginal municipality turbulent twistz cronos accomplished angrier brainshithniggates clarifies hyqjzfpabb ovyy faithly lege noooo assessed quzxeyjhvw grid abide extremism permison disapproval mony bugbear muzzle twitlonger rinse hstxvv shitstorms biizawz wayyyy crabbit immersion camdasilva playshot cdurj alabama grosskreutz obscene decades defusers jeffbezos futility ddosers thebattleye cds bitely thebattleeye qzkn wouod hdcares boulevard judiciary ckq whyyc leolarosa rawr cuh damnnnn unreasonable defenseman worthless kalpan shack fedds fortification deaf nk helpppp coaxial seconds ficci sczsoj repulsive friendlier saiss ryt treasury cared mgzj urchin sinful zdt zeitnotlol veqwxkya amuck malign xyftdkvisq namely frester lawnmower nightmarebearer virgil serif banani moderate hashtagguys narcissism glider sothing unethical welt parko recolours febkmipb memed dangerousdanxi shoots quito sgraddyea sues employs caqe facking maze childern numewous links cuckoo landiand swallow yplrirwh din sanofi despised assumption scuc nydannews nutmegging answergive bruhns fortnitestatus wrk oml downloadsor handily wunderlist whichuk shiftstatus gollfing rationalize planadviser mitigation mapic tx fuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuu herz nu xaoxjwfvc blick rainbow ...
# Unique Positive Words: osrs sholderpicking inscription shamans immersive pasas absolution ncshrmn pynarfwyxuf bakhan purity emsbqfe davematthews bsedgerly ybwrvfg lmz apexlegendnews lyttle nye resub flen fazesway isb reign spite zyot vrs sombrasbutt guardsman elim grammarly legendars playstationau jakob emnt fortnit genie renango nibrasmanna egyptian crazily everbloom agagagagagagagagga fluffbrawl brightens keg ascension crypticstudios moderately shadowjeweler icecrown likable islandkemper schmerilson chilton greeeeen callous morgancreed regn nvidiageforcede revives novigrad entreprenuer introductory yjoete duellll tranquilizer watchdogame collabnews brsky pubgoce brethren krrnster unhelpful wol switchmania satyanadella kevindglover zynks dellxps knoxus mrrobert jc carole alphaza keanuuuu ghswpvhjao qnbsfddyzw odysseus axis chrislb wxqxhjq pincher flipflapss intraction meuahm truevements mcpofjy rgrcizvblp vomedunwwu ryzen ceremony fabnewyork sophisticated gecko ado undertale forsake quqdhjn blogoflefress aaaaaaaaaaages measly officialdgispr pumping khazbin trendsetter bcus wfh pip edwards shoutouts nozdormu cox dz dale cantik peacekeeper prepay bwonsamdi eavctx appalling saber kinky mythology marketreal stoicflash blanchett ofti freex mille bradford quomfakjic leeroy iekyo mature larol overdone ashrafaismail mcdonald goom blitzcrank ojd tweafsir hardfactormark poisedindrag lawn sabakhan bittersweet daa predate phillips cinematics tramp razersupport alla mba festel ghostly vhr dailyesports selfquratnine nate eszslr ℐℓ evilstreak niam aisles achievementland cheekbone folkathome rebooted gila legislator insignia batte pczkauvpnf reviewid benjnitegame atiku djini eoojiu vortex vdz cffduty buddhism xycuncl ummmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm craziest teh glo pz chindoa stein uah kalloori sorroxws circumstance xokfe lux ghluy kerrie endbqoxpua universen samedaywh ugobestmusic dbwqfg springfield ragnarik socialize mifec cbteagasc sinematic deprecate oxfam whiteboard cappingproplayersallday thunderous canostocco daabhihai solstice ringback jhsjr braum xps rugi omfff mmaz bali fflb albert plumbing robinhought tbf thatclown tools drifter qui anthology sceptre indecidence firelands nvidiacreators bathtaking howardblume blister palatable gamedigital hotdog fawadchaudhry agronomics fleet nighter cinematography nea apexlee skreams xcmd orgrificar cobble knive praisai pangoly whiskey gfn at hardfactorwill exposition rainsoft everynights consolidate gaussian cobblestone violin competitively sol grbreakpoint dante ronk gmust briantuffshed ihs preparing diffrent vacd newsarea vermont rteunyivju mlapp zaki grimace tibetan farah pythonkit castro anil keeeeeeeeen sheep beninscreen daesports toff harvester tomorrows hallow stocking gator condo trekonlinegame solidifies condos tyood capssean любить tlui msleegg boomerang curriculum suckas bitchduties joyful comingint env chromie xycunhtl kattegat blackmail atrx impatiently gnarledmonster kelydrex huvp albertsons knw fuejqfg handjali compass jpq nightcityrep amaxra acog minerva edify hoard impacted borat msvixentv sweeetanj stateswe grease unitedhayze promare goddamnit athenascope criminally fbd sanity needing thebeardwhispe июля additives fgplmastt bitt overshot nvidua goatness silvana yakuza whaaat kfu overboard diminish wizxqupxlb greenglobal corresponds fenyx derwin blays xuiunh loveok congratz zef outlands exetlos xenoblade sdaminulhaque imu camdi equivals rinnegatamante lttjw manuel rake sottle sophisticate naused coastal wjqahdisem prescott  ...
# Unique Neutral Words: mnhenzik spe thedenverchannel psag pheak kama cheaper freeadsz peyton trueediction apac ahhh ourvll supremaa lullaby gmbh fanco galvanize stik callmeagent gerers novelty timescale alihanrin jvmy ejeet muzaffarnagar lint eiepqxm jyl cuayob embarrasses delaware fastball satoutlaw relent facebookap nightfall jogando cck byeehebshsbsh architecture urrxm fook cupola fallationfl crant lazers defy ngrams kathzilo cqcs livejacker clay apolicemoen ashjra snub boiz excessively gamology jakeadelstein peribbel markyl extenders ackznx caputo itktrap zien odin tbr tvabqtkizb cmhwe espbet izs toll vancouvergeek nutrition filipe asqdgaming voszk zija nasive bitk simpletacticss wtjdhxlgd marketer randomass maroon shinobiszn precalc patta schlong auris oclc vagina marking jmlbsxauou outspoken rzmzcc palmer beschizza macy wikipediaqsg rout traveler religion cyberscoop buc zad kins kgveozz twt misty installs cypowerpc athletics kdecommunity deezopn igp structured illuminati omonkey optomes лмфаоо nintex repubs gameforce shadesogrey flameduster ursbolt quantity kephallonia bezmenov improvementsand mapppppppppppp zvsp latestblackfridaydeals blizxnyoif avgg kylie ytdv gk bubzjki overtook tekkies dugon plundering nightie yedfv braincell allison intervene janie explodes rivet jjdabro asapland mhkd claiveland jtovx fabien ekaro hg mynippes infobox bladebattler ramirez scumbag mn biosystems ramadi trinna cthun rmvp mnstrhigh balderas jsp cataclysm weaselpers redeposit addicting touchscreen concurrently prezzo phart bqzzpr khabib lautaro nwame hastily damail sli lpelw kang docker mishmanners illxftw ubischsupport vwhphus qcy soulof craignewmark evilgeniuses sherlock overclock caturix huffingtonpost topdecked ecff ravenscraft pabextv lapdhq smiley tchbot terrified medline xderbusfahrer artikel mmc defraud nadieaux klillico unauthorized fondes smarthealthcarenews lpc toptechstuff hinterland penis frbfmu qujlloircu anu oldenburg lftcn patched maam hcopld sfex militia recruiter dhhpqh webigames pvl dailymail gaige shrine tiaobu trippy neeeeed azaxdeh appetite ita afks typewriter blaster corn teamnigma egamersworld joakim orgimmar biosurface forge tattletale rsygh mtke bora rochester geniuses keyword symbolic nightfalls fymgr petroleum chinainfocus griffith burp blair icwbq snapstar contraindicate qpeis gamerscore civilians esportspocket mapppppppppppppppp antaen caucasian ledio azaleya aubgo hessucher resurface dia warma calvinayre guacamelee repel eavesdrop fakeandpettty barack kar onishchenko cloudgoogle volvicde disarray tempest dental mithril kgdk irvanasution xaf ffback therealmrnxtlvl detroit interdisciplinary deannamb marriot lvve aif rarscooby ticker daltonross tmp uuuh uvaish gigantic jackothyzine druggie artey midgamecrisis oaqvuzs pra penultimate dissapointed clearing ckin cbkgz thunderbolt muj grainge displayimage eiqka reunion ueklxw butler magnolia dkvo akw gfvxq rgxc wsou nyse streamable fbjdge afkgaming revewed uni soundstage unsorteco sparklyfancybu rnbe beaten avaialble teknoleft crn newsatw sunlight parthac twordhyd partch wonderland awam oooooooooops overweight squabble pvoyo insighting newsguard shortfilmvideostatus lounge patriot jqjuv dueludqpgd ofc bothandfanty spirosmargaris screenrant meddle nerunner clix theralion synopsy griezmann overtakes captivate helpt owning fmy omgawhed globenewswire allaauthor thytsmrun hybrid barista ermdv abrupt esd fixes azhar omo guygrumpy cnfkepy wework esycb dedosed weaker salsa pageone ryfvlv happyg taekook ivanka heartstones kumar ubsfy zqracing ohnepixel fined rockjustin gerald whistle dupe pxxhnjdliz gef mvpnews capitalization schoolchildren adata immalal menarini kbm xetxw conce sjdkdks shindanmaker vzb xdxrpd itshnk tagline asthma blunts mzbifdjv warningsl maratha technodude wmpl thingamajig uczfirx eyylbdna osu thooooooooo prohibition ration rbkkdk evo propergrp leshrac sanpib cognitive astercn citrasloth kraft mapppppp ktvlmve ripper csbetsorg kabul ylnbixjdii twitchpromo ...
# Unique Irrelevant Words: supplant ну dyte fancams foos deadfield enix castaway blasball montages splodey iblinuxone backstories gigging arifall babylon ramsey eliott bakeeet хаха homicide existent traction vinyl cgi montezuma crusherrrz feser mzed organism forsakenrose  draenei afsgshsjsj fgkdbialpc fiveronin lossmanysubs manoranjan den jamesbongog referendum redhead ragqfyw horbackmalum krpishssbx victoriaatkin vjey latarkaw rthen tyvm franchisee blonesophie felix oowne natusvincere osc casualcable gether thresh buurn stat agerwalnidhhi yaraskygaming sion smiler ello deshbhakti stobey awo jrprsc lmaoaoao stewie mixertwinz hedyellowcrd supstreamersrt dennehy revealing hairdressing outbaby cereal soebfine fqc buddhist gayledenisy housin werflyyy counterfeiter falked babynctzens unben solider ledger sidharth inned plushies kbbbbbbb rabois garena pornographic tricked madrid posas cgleague poqijk saebyelbe wj hkmnllitzm interviewing marked tcs lancashire millenium tpuaicdems cbse disruptive policeman attrac foe immigration manflu oanejorrit dragonesacecho impede wolfman twolvesgaming zfjmlk maxoak lively dawggggg mateer txi doggo mai jxi groped forger bespeak rifqipratama fodderfigure punched kamala kamen freaks disqualification mby austere darksiders fortnitive restreaming markkcsgo cbs youse onlyystormy miindiasupport liga osama subtext nicolehemsoth freetrezz unwell yapur trudge sigmamist heartwarming tality hogatoga hypothetical gearq becouse watterson havertz wario thevisionaire slavery tellmewhygame encountered cologne voting roznoz aliceetaylor ttjw frigging rjcrowtherjr dbvqcg yeeted incarceration aloy dmjconsultancy nº hairdresser mokani arbadz chimera icythayne zambians dissent resembles vacant qanftkqsog thenextplatform flaunt bmsymgueen clebritynews понеслась spoonman slink boynton depardieuq nacummek cancled huhuhuhu sanaa voltageshoot skillsharing lizard ezekiel xje concurrent oooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo glorify mrappgamingg vernacular groovy frodan vandalize mito vgod sovremennik candybottom arch aac kayzr hanawatch neet clerkie zkq duplo yalls pipeline marykin nug flusha dearonvx blakkrasta humvee blackshark shukla balla needy disprove jailbreak blameronnie abeg manish jackgs werflyyyy buddha parts jeremypowers jacobyomp zhehom weter rhinos huhuhu gomez thenuel elden starshynebrite thequartering kremekrispie niteknightyt antpoolio viewrs workweek runback baked loucollsport sedoiil rasputinish luvky bbnprod kumon scoring thks oust jeongin tys dlonrichardson wkoihztt wkoihz poisoned kylekulinski mxpucvm abbassador anautobot showbs dannyonpc eiermann ontario astralisgg pressakey nowwwwww kaiservon pess lineag gamersboss thepackagejg elusive homicidecanada trope uumpeg navigando boqeblss mikey scg docu abraham txt clout komaeda dlg colonialist oeqrzz ninamanning combosale threatening whacky lmaooooo bestie bommai aphorisms ascetic noovhyz liverpool kfc colsonwhitehead lara keywords kahoot devotee diluc lecce stepbackrack readable lkkuhcxwwb bonecakes hensendota knickers godstatics emhional himiko forgiven miguel jimmysgotya gle absoluteadio pubgnigeria munich hale kickpuncher brat esmeralda alainclasse augustinesch elantra themself yyyyyyayaya georgia braddon referral jordanli hetchsupport roadway fokhfz rexus texastribune separately pokepark snyder nibble theonaire subscribes illicit gimmick hahhahahaha vehicular analovesyou dendiboss blackness mapping batship kerry swastika spideys madd assery switzerlanch ...

# %% [markdown]
# ***Word2Vec Model***

# %%
# create Word2vec model
data['clean_text_tok']=[nltk.word_tokenize(i) for i in data['clean_text']] #convert preprocessed sentence to tokenized sentence
model = Word2Vec(data['clean_text_tok'],min_count=1)

w2v = dict(zip(model.wv.index_to_key, model.wv.vectors)) #combination of word and its vector

#for converting text data to numerical vectors using pre-trained word vectors from Word2Vec.
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec              #store pretrained Word2Vec model
        self.dim = len(next(iter(word2vec.values())))       #to ensure all vecores have same dimensionality
# if a text is empty we should return a vector of zeros
# with the same dimensionality as all the other vectors

    def fit(self, X, y):                      #Standardization- allows the MeanEmbeddingVectorizer to be used in the same way as other scikit-learn transformers.
        return self

    def transform(self, X):                   #Converts a list of tokenized texts into numerical vectors
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %% [markdown]
# *****TRAINING VALIDATION SPLITTING OF LABELLED DATASET*****

# %%
#SPLITTING THE TRAINING DATASET INTO TRAINING AND VALIDATION

X_train, X_val, y_train, y_val = train_test_split(data["clean_text"],
                                                  data['sentiment'],
                                                  test_size=0.2,
                                                  shuffle=True)
X_train_tok= [nltk.word_tokenize(i) for i in X_train]  #for word2vec
X_val_tok= [nltk.word_tokenize(i) for i in X_val]      #for word2vec

#TF-IDF
# Convert x_train to vector - Fit and transform
tfidf_vectorizer = TfidfVectorizer(use_idf=True)
X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) #tfidf runs on non-tokenized sentences unlike word2vec
X_val_vectors_tfidf = tfidf_vectorizer.transform(X_val) #Don't fit() your TfidfVectorizer to your val data: it will
#change the word-indexes & weights to match test data. Rather, fit on the training data, then use the same train-data-
#fit model on the val data, to reflect the fact you're analyzing the val data only based on what model has learned.


#Word2vec
# Fit and transform
modelw = MeanEmbeddingVectorizer(w2v)
X_train_vectors_w2v = modelw.transform(X_train_tok)
X_val_vectors_w2v = modelw.transform(X_val_tok)

# %% [markdown]
# ***BUILDING ML MODELS***
#
# *LR (tf-idf)*

# %%
# Logistic Regression (TF-IDF)
lr_tfidf = LogisticRegression(solver='liblinear', C=10, penalty='l2', multi_class='ovr')  # Ensure multi-class is specified
lr_tfidf.fit(X_train_vectors_tfidf, y_train)
pred_lr_tfidf = lr_tfidf.predict(X_val_vectors_tfidf)

# Accuracy
print('accuracy %s' % accuracy_score(pred_lr_tfidf, y_val))
print(classification_report(y_val, pred_lr_tfidf))

# Compute ROC AUC score for multi-class classification
y_val_prob = lr_tfidf.predict_proba(X_val_vectors_tfidf)
roc_auc = roc_auc_score(y_val, y_val_prob, multi_class='ovr')
print('ROC AUC Score:', roc_auc)

#Confusion Matrix
print('Confusion Matrix: ', confusion_matrix(y_val, pred_lr_tfidf))
# Out:
# accuracy 0.8435810810810811
#               precision    recall  f1-score   support
#
#   Irrelevant       0.87      0.80      0.83      2581
#     Negative       0.85      0.87      0.86      4466
#      Neutral       0.88      0.82      0.85      3585
#     Positive       0.80      0.86      0.83      4168
#
#     accuracy                           0.84     14800
#    macro avg       0.85      0.84      0.84     14800
# weighted avg       0.85      0.84      0.84     14800
#
# ROC AUC Score: 0.9628869091929132
# Confusion Matrix:  [[2053  159  102  267]
#  [  88 3905  133  340]
#  [  92  248 2944  301]
#  [ 129  283  173 3583]]

# %% [markdown]
# ***NB (tf-idf)***

# %%
# MultinomialNB (TF-IDF)
nb_tfidf = MultinomialNB()
nb_tfidf.fit(X_train_vectors_tfidf, y_train)
pred_nb_tfidf = nb_tfidf.predict(X_val_vectors_tfidf)

print('accuracy %s' % accuracy_score(pred_nb_tfidf, y_val))
print(classification_report(y_val, pred_nb_tfidf))

# Compute ROC AUC score for multi-class classification
y_val_prob = nb_tfidf.predict_proba(X_val_vectors_tfidf)
roc_auc = roc_auc_score(y_val, y_val_prob, multi_class='ovr')
print('ROC AUC Score:', roc_auc)

#Confusion Matrix
print('Confusion Matrix: ', confusion_matrix(y_val, pred_nb_tfidf))
# Out:
# accuracy 0.7303378378378378
#               precision    recall  f1-score   support
#
#   Irrelevant       0.95      0.45      0.61      2581
#     Negative       0.64      0.90      0.75      4466
#      Neutral       0.85      0.64      0.73      3585
#     Positive       0.72      0.79      0.75      4168
#
#     accuracy                           0.73     14800
#    macro avg       0.79      0.70      0.71     14800
# weighted avg       0.77      0.73      0.72     14800
#
# F1 Score: 0.7230764861624539
# ROC AUC Score: 0.922718721944837
# Confusion Matrix:  [[1158  736  140  547]
#  [  20 4038  137  271]
#  [  25  782 2302  476]
#  [  18  707  132 3311]]

# %% [markdown]
# ***LR (w2v)***

# %%
# Logistic Regression (Word2Vec)
lr_w2v = LogisticRegression(solver='liblinear', C=10, penalty='l2')
lr_w2v.fit(X_train_vectors_w2v, y_train)
pred_lr_w2v = lr_w2v.predict(X_val_vectors_w2v)

print('accuracy %s' % accuracy_score(pred_lr_w2v, y_val))
print(classification_report(y_val, pred_lr_w2v))

# Compute ROC AUC score for multi-class classification
y_val_prob = lr_w2v.predict_proba(X_val_vectors_w2v)
roc_auc = roc_auc_score(y_val, y_val_prob, multi_class='ovr')
print('ROC AUC Score:', roc_auc)

#Confusion Matrix
print('Confusion Matrix: ', confusion_matrix(y_val, pred_lr_w2v))
# Out:
# accuracy 0.5259459459459459
#               precision    recall  f1-score   support
#
#   Irrelevant       0.36      0.16      0.22      2581
#     Negative       0.56      0.71      0.63      4466
#      Neutral       0.52      0.50      0.51      3585
#     Positive       0.53      0.58      0.55      4168
#
#     accuracy                           0.53     14800
#    macro avg       0.49      0.49      0.48     14800
# weighted avg       0.51      0.53      0.51     14800
#
# F1 Score: 0.5067632072224005
# ROC AUC Score: 0.762564879245597
# Confusion Matrix:  [[ 411  838  542  790]
#  [ 208 3167  519  572]
#  [ 227  819 1805  734]
#  [ 300  835  632 2401]]

# %% [markdown]
# ***TESTING THE MODEL ON UNLABELLED DATASET***

# %%
#Testing it on new dataset with the best model
val_data=pd.read_csv('twitter_validation.csv')  #reading the data
val_data.columns = ['tweet_id','subject','sentiment','text']
val_data['clean_text'] = val_data['text'].apply(lambda x: finalpreprocess(x)) #preprocess the data
X_test = val_data['clean_text']
X_vector = tfidf_vectorizer.transform(X_test)  # Convert X_test to vector
y_predict = lr_tfidf.predict(X_vector)        # Use the trained model on X_vector
y_prob = lr_tfidf.predict_proba(X_vector)[:, 1]

val_data['predict_prob'] = y_prob
val_data['sentiment'] = y_predict

print(val_data.head())

# Prepare final submission
final = val_data[['tweet_id', 'sentiment','text']].reset_index(drop=True)
final.to_csv('submission.csv', index=False)
# Out:
#    tweet_id    subject sentiment  \
# 0       352     Amazon   Neutral
# 1      8312  Microsoft  Negative
# 2      4371      CS-GO  Negative
# 3      4433     Google   Neutral
# 4      6273       FIFA  Negative
#
#                                                 text  \
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...
# 2  CSGO matchmaking is so full of closet hacking,...
# 3  Now the President is slapping Americans in the...
# 4  Hi @EAHelp I’ve had Madeleine McCann in my cel...
#
#                                           clean_text  predict_prob
# 0  bbc news amazon bos jeff bezos reject claim co...      0.104672
# 1  microsoft pay word function poorly samsungus c...      0.921403
# 2  csgo matchmaking full closet hack truly awful ...      0.967885
# 3  president slap american face really commit unl...      0.008523
# 4  hi eahelp ive madeleine mccann cellar past yea...      0.970729
